# %%
from distutils.core import setup

from Cython.Build import cythonize

#setup(ext_modules=cythonize('fib.pyx'))

# %%
# Comparing Python, C and Cython

#Py

def fibB(n):
    a,b = 0.0, 1.0
    for i in range(n):
        a, b = a + b, a
    return a

# %%
# C

double CfibB(int n) {
    int i;
    double a=0.0, b=1.0, tmp;
    for (i=o; i<n; ++i) {
        tmp = a; a = a + b; b = tmp;
    }
    return a;
    
}
# Out:
#   Input In [8]
#     double CfibB(int n) {
#            ^
# SyntaxError: invalid syntax

# %%
# Cython
cdef Cyfib(int n):
    cdef int int
    cdef double a=0.0, b=1.0
    for i in range(n):
        a, b = a + b, a
    return a
# Out:
#   Input In [9]
#     cdef Cyfib(int n):
#          ^
# SyntaxError: invalid syntax

# %%
cdef extern from "cfib.h":
    double fib(int n)
    
def fib(n):
    return cfib(n)
# Out:
#   Input In [10]
#     cdef extern from "cfib.h":
#          ^
# SyntaxError: invalid syntax

# %%
# Compiling and Running Cython Code

# %%
import fib

# %%
# interactive Cython with Ipythons %% cython Magic
# %load_ext Cython

# %%
# %%cython -a
#
# def  hello_nip():
#     print('Hello, World')
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.28 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_4dd47ad6b444a27d2a2bac077919a46f.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %%
# %%cython
# import numpy as np
#
# def  max(int a, int b):
#     return a if a > b else b
#
#
#
# catch = max(22, 25)

# %%
catch
# Out:
# 25

# %%
# %%cython
#
# def fib(int n):
#     cdef int i
#     cdef double a=0.0, b=1.0
#     for i in range(n):
#         a, b = a + b, a
#     return a
#
# res = fib(90)

# %%
res
# Out:
# 2.880067194370816e+18

# %%
# Compiling On the Fly with pyximport



import pyximport

pyximport.install()
# Out:
# (None, <pyximport.pyximport.PyxImporter at 0x1b234d5b970>)

# %%
# We can use pyximport in an interactive  UPython session to compile and load .pyx files
# with pyximport installed we can import fib as if it was a pyfile

# %%
import fib

import cython

# %%
fib.__file__
# Out:
# 'c:\\Users\\JBarr\\OneDrive\\Documents\\FinTech\\CythonPower\\fib.cp38-win_amd64.pyd'

# %%
type(fib)
# Out:
# module

# %%
fib.fib(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\JBarr\OneDrive\Documents\FinTech\CythonPower\cythonNews.ipynb Cell 20' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JBarr/OneDrive/Documents/FinTech/CythonPower/cythonNews.ipynb#ch0000019?line=0'>1</a> fib.fib(20)
#
# AttributeError: module 'fib' has no attribute 'fib'

# %%
# %%cython
#
# import cython
# def fast_indexing(a):
#     with cython.boundscheck(False), cython.wraparound(False):
#         for i in range(len(a)):
#             sum += a[i]

# %%
    """
    Dynamically typed variables in Cython come for free
    we simply assign to a variables to initialize it
    and use it as we would in Py
    """
# Out:
# '\nDynamically typed variables in Cython come for free\nwe simply assign to a variables to initialize it\nand use it as we would in Py\n'

# %%
a = [x+1 for x in range(12)]
b = a
a[3] = 42.0
assert b[3] == 42.0
a = 13
assert isinstance(b, list)

# %%
# %%cython
# import cython
#
# cdef int i
# cdef int j
# cdef float k

# %%
j = 0 
i = j 
k = 12.0
j = 2 * k
assert i != j

# %%
'We can declare several var of same kind at once'

# %%
# %%cython
# import cython
#
# cdef int i, j, k
#
# cdef float price, margin

# %%
# %%cython
# import cython
#
# cdef int i = 0
# cdef long int  j = 0 , k = 0
# cdef float price2 = 0.0, margin = 1.0

# %%
# %%cython
# import cython
#
# def integrate(a,b,f):
#     cdef int i
#     cdef int N=2000
#     cdef float dx, s=0.0
#     dx = (b-a)/N
#     for i in range(N):
#         s += f(a+i*dx)
#     return s * dx

# %%
"""
    Equivalent way to seclare multiple vaiables is by means of a cdef block,
    which groups declarations in an indended region.
"""

def integrate(a, b, f):
    cdef:
        int i
        int N=2000
        float dx, s=0.0
# Out:
#   Input In [49]
#     cdef:
#          ^
# SyntaxError: invalid syntax

# %%
# Automatic Type inference in Cython
# To enable type inference for a function, we can use the decorator form of infer_types:
def automatic_inference():
    i = 1
    d = 2.0
    c = 3+4j
    r = i * d + c
    return r

# %%
# %%cython
# import cython
#
# @cython.infer_types(True)
# def automatic_inference():
#     i = 1
#     d = 2.0
#     c = 3+4j
#     r = i * d + c
#     return r

# %%
# C Pointers in Cython
# %%cython 
import cython


cdef float** pp_float = NULL
# Out:
#   Input In [57]
#     cdef float** pp_float = NULL
#          ^
# SyntaxError: invalid syntax

# %%
# Mixing Statically and Dynamically Typed Variables

# %%
# %%cython
# import cython
#
# cdef int a, b, c
# tuple_ofInts = (a,b,c)

# %%
# Statically Declaring Variables with a Python Type
# Built-in types like list,tupe,dict can declared via:

# %%
# %%cython
# import cython
#
# cdef list particles = []
#
# cdef dict names_of = {}
#
# cdef str pname = ''
# cdef set unique_parts = set()

# %%
'''
Full Py objects. Under the hood, Cython declares them as C pointers to some built-in Py struct type.
Can be used like ordinary py vars but are constrained to their declared types:


'''
# Out:
# '\nFull Py objects. Under the hood, Cython declares them as C pointers to some built-in Py struct type.\nCan be used like ordinary py vars but are constrained to their declared types:\n\n\n'

# %%
cdef

cdef
cdef


cdef
cdef

cdef
cdef
